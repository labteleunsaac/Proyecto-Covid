# %%
from glob import glob

# %%
glob("C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\*")
# Out:
# ['C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-17-30_P_0_36.1.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-18-49_P_1_37.6.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-18-54_P_1_36.9.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-19-31_P_0_37.1.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-35-38_P_0_36.6.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-35-57_P_0_36.3.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\12-25-47_P_0_36.7.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\12-26-41_P_0_37.9.jpg']

# %%
filelist=glob("C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\*")

# %%
filelist
# Out:
# ['C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-17-30_P_0_36.1.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-18-49_P_1_37.6.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-18-54_P_1_36.9.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-19-31_P_0_37.1.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-35-38_P_0_36.6.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\11-35-57_P_0_36.3.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\12-25-47_P_0_36.7.jpg',
#  'C:\\Users\\invitado_liistti\\Desktop\\FOTOS\\sin mascara\\12-26-41_P_0_37.9.jpg']

# %%
from time import time

# %%
import cv2
import os
#from keras.models import load_model
import numpy as np
#from pygame import mixer
from time import time
from label_detect import classify_face

# %%
for image in filelist:
    tic=time()
    img=cv2.imread(image,1)
    label = classify_face(img)
    toc=time()-tic
    print(toc, img.shape)
# Out:
# image_processed
# tensor([[ 0.2937, -0.3467]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(0) predicted
# with_mask
# 0.4809396266937256 (190, 320, 3)
# image_processed
# tensor([[-3.6849,  4.2299]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# 0.2932162284851074 (567, 579, 3)
# image_processed
# tensor([[-2.3466,  2.7364]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# 0.2822451591491699 (462, 498, 3)
# image_processed
# tensor([[0.0372, 0.0269]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(0) predicted
# with_mask
# 0.3011941909790039 (467, 537, 3)
# image_processed
# tensor([[-3.2348,  3.7022]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# 0.30219149589538574 (479, 519, 3)
# image_processed
# tensor([[ 0.8645, -0.9727]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(0) predicted
# with_mask
# 0.29920005798339844 (434, 528, 3)
# image_processed
# tensor([[-3.5588,  3.9746]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# 0.3031895160675049 (444, 496, 3)
# image_processed
# tensor([[-0.8514,  1.2110]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# 0.3001978397369385 (404, 464, 3)

# %%
help(time)
# Out:
# Help on built-in function time in module time:
#
# time(...)
#     time() -> floating point number
#
#     Return the current time in seconds since the Epoch.
#     Fractions of a second may be present if the system clock provides them.

# %%
import numpy as np
import time
import cv2

cap = cv2.VideoCapture('rtsp://admin:admin@192.168.1.73/cam1/mpeg4')
#cap = cv2.VideoCapture('rtsp://admin:admin@192.168.1.73:554/cam/realmonitor?channel=0&subtype=0')
#cap = cv2.VideoCapture(0)

#cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
#cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
i=0
for i in range(5):
    
    

    #print('About to start the Read command')
    ret, frame = cap.read()
    #print('About to show frame of Video.')
    #cv2.imshow("Capturing",frame)
    print(frame.shape)
    ROI = frame[200:1000, 650:1300]
    print(ROI.shape)
    
    cv2.imwrite('img'+str(i)+'.png', ROI)
    #print('Running..')
    time.sleep(1)
    i+=1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# (1080, 1920, 3)
# (800, 650, 3)
# (1080, 1920, 3)
# (800, 650, 3)
# (1080, 1920, 3)
# (800, 650, 3)
# (1080, 1920, 3)
# (800, 650, 3)
# (1080, 1920, 3)
# (800, 650, 3)

# %%
from time import sleep

for i in range(5):
    print('Hello')
    sleep(5)
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-07dcab72862b> in <module>
#       3 for i in range(5):
#       4     print('Hello')
# ----> 5     sleep(5)
#
# KeyboardInterrupt:

# %%
image
# Out:
# '.\\img4.png'

# %%
img=cv2.imread(image,1)

# %%
img.shape
# Out:
# (800, 650, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(img)
